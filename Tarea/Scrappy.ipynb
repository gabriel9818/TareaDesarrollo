# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel9818/TareaDesarrollo/blob/main/Tarea/Scrappy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación de las librerias o dependencias necesarias
# !pip install beautifulsoup4 requests pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Load dependencies
import json # modulo para trabajar con archivos JSON
import requests # libreria para hacer peticiones HTTP
import pandas as pd # libreria para procesar datos, proporciona funciones para analíticas
from bs4 import BeautifulSoup as bs # Extraer información de paginas web

# %%
# Función que convierte una lista de elementos en un dataframe de pandas
def rowsToDataFrame(rows):
    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

# %%
# Función para extraer los datos de una tabla HTML
def processTableData(tbl):
    rows = []
    for child in tbl.find('tbody').children: # itera los items internos de la tabla [<tr>]
        row = []
        for td in child: # itera los items internos de la tabla [<td>]
            try:
                item = td.text.replace('\n', '') # recupera el texto del elemento [<td>]
                if item:
                    row.append(item) # Agrega cada elemento de la fila
            except:
                continue
        if len(row) > 0:
            rows.append(row) # agrega todos los campos de una fila de la tabla
    # print(rows)
    return rows

# %%
# Función para exxtrar la data de la URL y procesar el contenido HTML
def processDataHTML(data):
    soup = bs(data['sections'][1]['text'], 'html.parser') # Recupera el item del JSON y lo convierte en contenido HTML
    tbl = soup.find_all('table')[0] # Recupera la tabla del contenido HTML
    # print(tbl.prettify())
    tblRows = processTableData(tbl) # Ejecuta la función apra porcesar el contenido de la Tabla
    return tblRows

# %%
# Read website
# r = requests.get('https://www.wikiwand.com/es/Anexo:Tabla_estadística_de_la_Copa_Mundial_de_Fútbol')
r = requests.get('https://www.wikiwand.com/mcs-api/es.wikipedia.org/v1/page/mobile-sections-remaining/Anexo%3ACronolog%C3%ADa_de_epidemias')  # Recuperamos el contenido de la web
# print(r)
table = processDataHTML(json.loads(r.content)) # Formate el contenido en formato JSON
df = rowsToDataFrame(table) # ejecuta la funcion para recupera los datos de la tabla como dataframe de Pandas
df
# Out:
#    N.º                                         Nombre     Inicio      Final  \
# 0    1                                  Peste negra †       1347       1353
# 1    2                    Pandemia de gripe de 1918 †       1918       1920
# 2    3                               Pandemia de sida       1981   Presente
# 3    4                          Plaga de Justiniano †        541        549
# 4    5                         Tercera plaga bubónica       1855       1960
# 5    6                 Epidemia de cocolitzli de 1545       1545       1548
# 6    7            Epidemia de viruela en Tenochtitlán       1519       1520
# 7    8                           Pandemia de COVID-19       2019   Presente
# 8    9                                 Peste antonina        165        180
# 9   10                         Epidemia rusa de tifus       1918       1922
# 10  11                 Epidemia de cocolitzli de 1576       1576       1580
# 11  12                   Epidemia de viruela japonesa        735        737
# 12  13                                    Peste persa       1772       1773
# 13  14                                 Gripe asiática       1957       1958
# 14  15              Pandemia de encefalitis letárgica       1915       1926
# 15  16                               Peste de Nápoles       1656       1660
# 16  17                             Gripe de Hong Kong       1968       1969
# 17  18                         Pandemia de gripe rusa       1889       1890
# 18  19           Plaga italiana (Gran Peste de Milán)       1629       1631
# 19  20                     Tercera pandemia de cólera       1846       1860
# 20  21                                 Peste cipriana        250        266
# 21  22                                  Peste egipcia       1609       1610
# 22  23                       Sexta pandemia de cólera       1899       1923
# 23  24                                     Gripe rusa       1977       1979
# 24  25                     Epidemia de peste española       1596       1602
# 25  26                      Cuarta pandemia de cólera       1863       1875
# 26  27                    Epidemia de viruela europea       1870       1875
# 27  28        Epidemia de tripanosomiasis en el Congo       1896       1906
# 28  29              Epidemia de peste otomana de 1812       1812       1819
# 29  30                     Epidemia de tifus en Rusia       1812       1813
# 30  31                      Quinta pandemia de cólera       1881       1896
# 31  32                            Pandemia de gripe A       2009       2010
# 32  33          Epidemia de tripanosomiasis en Uganda       1900       1920
# 33  34  Epidemia de peste en la Gran Guerra del Norte       1710       1712
# 34  35               Epidemia de malaria del Pacífico       1829       1833
# 35  36                                Plaga de Atenas  429 a. C.  425 a. C.
# 36  37                          Gran peste de Londres       1665       1666
# 37  38                         Gran peste de Marsella       1720       1722
# 38  39                     Segunda pandemia de cólera       1826       1837
# 39  40                     Primera pandemia de cólera       1817       1824
#
#                             Patógeno           Muertes   Ref
# 0           Yersinia pestis 2ª Plaga    100 Millones +   [1]
# 1   Influenzavirus A H1N1 - Mutación    100 Millones +   [1]
# 2                                VIH     40 Millones +   [2]
# 3           Yersinia pestis 1ª Plaga     50 Millones +   [3]
# 4           Yersinia pestis 3ª Plaga     15 Millones +   [4]
# 5                Salmonella enterica  12-15 Millones +   [5]
# 6                            Viruela    8.0 Millones +   [6]
# 7                         SARS-CoV-2    6.9 Millones +   [7]
# 8                        Desconocido    5.0 Millones +   [8]
# 9                         Rickettsia    3.0 Millones +   [9]
# 10               Salmonella enterica    2.0 Millones +  [10]
# 11                           Viruela    2.0 Millones +  [11]
# 12                   Yersinia pestis    2.0 Millones +  [12]
# 13     Influenzavirus A H2N2 - Aviar    1.5 Millones +   [1]
# 14                       Desconocido    1.5 Millones +  None
# 15                   Yersinia pestis    1.2 Millones +  [13]
# 16             Influenzavirus A H3N2    1.1 Millones +   [1]
# 17                         HCoV-OC43    1.0 Millones +  [14]
# 18                   Yersinia pestis    1.0 Millones +  [15]
# 19                            Cólera    1.0 Millones +  [16]
# 20                       Desconocido    1.0 Millones +  None
# 21                   Yersinia pestis         900.000 +  None
# 22                            Cólera         800.000 +  [17]
# 23             Influenzavirus A H1N1         700.000 +  [18]
# 24                   Yersinia pestis         700.000 +  None
# 25                            Cólera         600.000 +  None
# 26                           Viruela         500.000 +  None
# 27          Tripanosomiasis africana         500.000 +  None
# 28                   Yersinia pestis         300.000 +  None
# 29                        Rickettsia         300.000 +  None
# 30                            Cólera         298.600 +  None
# 31   Influenzavirus A H1N1 - Porcina         284.000 +  None
# 32            Tripanomiasis africana         250.000 +  None
# 33                   Yersinia pestis         164.000 +  None
# 34                           Malaria         150.000 +  None
# 35                       Desconocido         100.000 +  None
# 36                   Yersinia pestis         100.000 +  None
# 37                   Yersinia pestis         100.000 +  None
# 38                            Cólera         100.000 +  None
# 39                            Cólera         100.000 +  None

# %%
# Inspeccionamos el tipo de dato de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N.º       40 non-null     object
#  1   Nombre    40 non-null     object
#  2   Inicio    40 non-null     object
#  3   Final     40 non-null     object
#  4   Patógeno  40 non-null     object
#  5   Muertes   40 non-null     object
#  6   Ref       21 non-null     object
# dtypes: object(7)
# memory usage: 2.3+ KB

# %%
# Guardamos las datos extraidos como archivo CSV
# se puede aplcair otras opciones para guardar (Base de datos)
df.to_csv('EpidemiasMundiales.csv')
